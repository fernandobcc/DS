# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset('tips') # carrega dataset que já tem por padrão
flights = sns.load_dataset('flights')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill']) #plot uma variável, ou seja plot de uma coluna com os valores escolhidos
# Out:
# C:\Users\Fernando\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(tips['total_bill'], kde=False) 
plt.show()
# Out:
# C:\Users\Fernando\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(tips['total_bill'], kde=False, bins=30)  # para aumentar o número de caixas

# %%
sns.jointplot(x='total_bill',y='tip',data=tips) #permite combinar 2 diferentes plots (x,y,dataset)
# Out:
# C:\Users\Fernando\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde') #kind o tipo de plot interno
# Out:
# C:\Users\Fernando\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(tips) #Plota cruzamento de todos os dados numericos do data set. Similar a jointplot mas com todos os dados

# %%
sns.pairplot(tips, hue='sex',palette='coolwarm') #com vc add dados não num nos graficos e com palette altera-se o padrão de cor
# Out:
# C:\Users\Fernando\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.rugplot(tips['total_bill'])

# %%
sns.distplot(tips['total_bill'], kde=True) #kde = kernel density estimation
# Out:
# C:\Users\Fernando\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Don't worry about understanding this code!
# It's just for the diagram below
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

#Create dataset
dataset = np.random.randn(25)

# Create another rugplot
sns.rugplot(dataset);

# Set up the x-axis for the plot
x_min = dataset.min() - 2
x_max = dataset.max() + 2

# 100 equally spaced points from x_min to x_max
x_axis = np.linspace(x_min,x_max,100)

# Set up the bandwidth, for info on this:
url = 'http://en.wikipedia.org/wiki/Kernel_density_estimation#Practical_estimation_of_the_bandwidth'

bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2


# Create an empty kernel list
kernel_list = []

# Plot each basis function
for data_point in dataset:
    
    # Create a kernel for each point and append to list
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    #Scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis,kernel,color = 'grey',alpha=0.5)

plt.ylim(0,1)
# Out:
# (0, 1)

# %%
# To get the kde plot we can sum these basis functions.

# Plot the sum of the basis function
sum_of_kde = np.sum(kernel_list,axis=0)

# Plot figure
fig = plt.plot(x_axis,sum_of_kde,color='indianred')

# Add the initial rugplot
sns.rugplot(dataset,c = 'indianred')

# Get rid of y-tick marks
plt.yticks([])

# Set title
plt.suptitle("Sum of the Basis Functions")
# Out:
# Text(0.5, 0.98, 'Sum of the Basis Functions')

# %% [markdown]
# ## Aula 49 - Categorical plots

# %%
sns.barplot(x='sex',y='total_bill', data=tips) #vizualisar um grupo por sua ação. Ou seja associar uma campo de categoria com
#númerico. No exemplo associa-se o sexo com a media do total de contas
# Out:
# C:\Users\Fernando\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
import numpy as np

# %%
sns.barplot(x='sex',y='total_bill', data=tips, estimator=np.std) #estimator serve para dizer como vai ser a associação 
#numerica com a categoria. Por examplo, média, desvio padrão, etc.
# Out:
# C:\Users\Fernando\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.countplot(x='sex',data=tips) #similar ao barplot mas nesse caso conta-se o número de ocorrencias

# %%
sns.boxplot(x='day',y='total_bill',data=tips) #faz o bloxplot, lembre-se dos quadrantes, outliers e de seu signicado.

# %%
sns.boxplot(x='day',y='total_bill',data=tips, hue='smoker') #adiciona-se hue para adicionar mais uma categoria

# %%
sns.violinplot(x='day',y='total_bill',data=tips, hue='sex') #similar com o boxplot mas mostra todo os componentes e sua densidade
# Out:
# C:\Users\Fernando\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.violinplot(x="day", y="total_bill", data=tips, hue='sex',split=True) 
#com slipt= true é posivel agregar as informações em 
#um só objeto de representação, o que facilita a vizualição e coloca mais informações no gráfico. No boxplot isso não é possível
# Out:
# C:\Users\Fernando\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.stripplot(x='day', y='total_bill', data=tips, jitter=True, hue='sex', split=True) #grafico dos pontos mas com categoria
#jitter serve para representar melhor as
# Out:
# C:\Users\Fernando\Anaconda3\lib\site-packages\seaborn\categorical.py:2775: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='day', y='total_bill', data=tips) #similar a striplot + violinplot

# %%
sns.violinplot(x="day", y="total_bill", data=tips)
sns.swarmplot(x='day', y='total_bill', data=tips,color='black') #caso queira associar os gráficos
# Out:
# C:\Users\Fernando\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.factorplot(x="day", y="total_bill", data=tips,kind='bar') # possível gerar diferentes tipos de gráficos apenas 
#trocando o tipo de kind
# Out:
# C:\Users\Fernando\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Fernando\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.factorplot(x="day", y="total_bill", data=tips,kind='violin') # possível gerar diferentes tipos de gráficos apenas 
#trocando o tipo de kind
# Out:
# C:\Users\Fernando\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Fernando\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Matrix PLot

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
tips.corr() # coloca em forma de matrix
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
tc = tips.corr()

# %%
sns.heatmap(tc) #faz uma mapa de calor

# %%
sns.heatmap(tc, annot=True, cmap='coolwarm') #annot faz aparecer os valores e cmap muda padrão de cor

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# 5    1949       June         135
# 6    1949       July         148
# 7    1949     August         148
# 8    1949  September         136
# 9    1949    October         119
# 10   1949   November         104
# 11   1949   December         118
# 12   1950    January         115
# 13   1950   February         126
# 14   1950      March         141
# 15   1950      April         135
# 16   1950        May         125
# 17   1950       June         149
# 18   1950       July         170
# 19   1950     August         170
# 20   1950  September         158
# 21   1950    October         133
# 22   1950   November         114
# 23   1950   December         140
# 24   1951    January         145
# 25   1951   February         150
# 26   1951      March         178
# ...

# %%
fp=flights.pivot_table(index='month', columns='year', values='passengers') # para transforma o mês no index, as colunas serem anos
#e os passageiros serem os valores

# %%
sns.heatmap(fp)

# %%
sns.heatmap(fp,cmap='coolwarm',linecolor='white',linewidths=1)

# %% [markdown]
# sns.clustermap(fp,cmap='coolwarm',standard_scale=1) #Junta dos dados por similaridade, standard_scale=rescalona

# %% [markdown]
# ## AULA 51 - GRID

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(iris)

# %%
g=sns.PairGrid(iris) #Pairgrid de dá um pouco mais de controle em comparação com pairplot
g.map(plt.scatter) #aqui vc escolhe o tipo de plot que vc quer

# %%
g=sns.PairGrid(iris) #observe a variedade de plot vc pode fazer o mesmo pairgrid em posições diferentes
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)
# Out:
# C:\Users\Fernando\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g=sns.FacetGrid(data=tips,col='time',row='smoker') #similar ao subplot da matplotlib
g.map(sns.distplot,'total_bill') #separa os plots por tipo e já coloca a lable para nos
# Out:
# C:\Users\Fernando\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
g=sns.FacetGrid(data=tips,col='time',row='smoker') #similar ao subplot da matplotlib
g.map(plt.scatter,'total_bill','tip') #para esse caso precisa de 2 argumentos pois o plot do tipo scatter pede isso

# %% [markdown]
# ## Aula 52

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['o','v'],scatter_kws={'s':100}) 
#observe-se que se pode passar matplotlip parametros
#em para seaborn com essa função. Passamos por examplo a marker para trocar os pontos  e scatter_kws para alterar o tamanho
#dos pontos
# Out:
# C:\Users\Fernando\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex', row='time') #col separa em duas colunas, row em linhas
# Out:
# C:\Users\Fernando\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day', hue='sex',aspect=0.6,size=8) #col separa em duas colunas, row em linhas
# Out:
# C:\Users\Fernando\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\Fernando\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## AULA 53 - Style and colors

# %%
sns.set_style('whitegrid') #permite trocar o estilo de visualização
sns.countplot(x='sex',data=tips)

# %%
sns.set_style('darkgrid') #permite trocar o estilo de visualização
sns.countplot(x='sex',data=tips)

# %%
sns.set_style('ticks') #permite trocar o estilo de visualização
sns.countplot(x='sex',data=tips)

# %%
sns.set_style('ticks') #permite trocar o estilo de visualização
sns.countplot(x='sex',data=tips)
sns.despine() #remove o quadrado da borda

# %%
sns.set_style('ticks') #permite trocar o estilo de visualização
sns.countplot(x='sex',data=tips)
sns.despine(left=True,bottom=True) #remove o quadrado da borda

# %%
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)

# %%
sns.set_context('poster',font_scale=3) #altera o contexto por exemplo papel ou poster ou etc
sns.countplot(x='sex',data=tips)

# %%
sns.set_context('paper') #altera o contexto por exemplo papel ou poster ou etc
sns.countplot(x='sex',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips, hue='sex', palette='seismic') #palette pode ser alterada para varios estilos dif.
#para isso basta procurar por matplotlib colormap
# Out:
# C:\Users\Fernando\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
